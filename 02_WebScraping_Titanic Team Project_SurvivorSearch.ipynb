# %% [markdown]
# # Search for one of the Survivor's Information

# %% [markdown]
# ## Import needed libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Read .csv files into variables

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %% [markdown]
# ## Combine Datasets

# %%
titanic_all = pd.concat([train_data, test_data], sort=True).reset_index(drop=True)

# %%
titanic_all.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# ...

# %% [markdown]
# ## Read into a dataframe the Webscraped survivor stories
# ### contains Passenger and Crew

# %%
survivor_df = pd.read_csv('survivor_df.csv')

# %%
survivor_df.rename(columns = {'Unnamed: 0':'Name'}, inplace = True)

# %%
# Add column to distinguish Passenger from Crew
status = ['Passenger', 'Passenger', 'Passenger', 'Passenger', 'Crew', 'Passenger', 'Passenger', 'Crew', 'Crew', 'Passenger', 'Passenger', 'Passenger', 'Crew', 'Passenger', 'Passenger', 'Passenger']

# %%
#insert new column in first position
survivor_df.insert(1, 'Status', status)

# %%
survivor_df
# Out:
#                           Name     Status  \
# 0                Millvina Dean  Passenger
# 1                  Bruce Ismay  Passenger
# 2         The Navratil orphans  Passenger
# 3   Cosmo and Lucy Duff Gordon  Passenger
# 4                Violet Jessop       Crew
# 5              Madeleine Astor  Passenger
# 6               Dorothy Gibson  Passenger
# 7              Frederick Fleet       Crew
# 8              Charles Joughin       Crew
# 9             Eva Miriam Harts  Passenger
# 10         Archibald Gracie IV  Passenger
# 11             Henry S. Harper  Passenger
# 12          Charles Lightoller       Crew
# 13              Margaret Brown  Passenger
# 14             Masabumi Hosono  Passenger
# 15                 Nöel Leslie  Passenger
#
# ...

# %% [markdown]
# ## Search for a Passenger by last name in the Titanic Dataset to find out more information:

# %%
titanic_all[titanic_all['Name'].str.contains('Hosono')]
# Out:
#       Age Cabin Embarked  Fare                  Name  Parch  PassengerId  \
# 288  42.0   NaN        S  13.0  Hosono, Mr. Masabumi      0          289
#
#      Pclass   Sex  SibSp  Survived  Ticket
# 288       2  male      0       1.0  237798
